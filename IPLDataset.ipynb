# %%
import pandas as pd 
import numpy as np

# %%
first_dataset = pd.read_csv("deliveries.csv")
second_dataset = pd.read_csv("matches.csv")

first_dataset.head()
# Out:
#        ID  innings            BattingTeam                  BowlingTeam  overs  \
# 0  335982        1  Kolkata Knight Riders  Royal Challengers Bangalore      0
# 1  335982        1  Kolkata Knight Riders  Royal Challengers Bangalore      0
# 2  335982        1  Kolkata Knight Riders  Royal Challengers Bangalore      0
# 3  335982        1  Kolkata Knight Riders  Royal Challengers Bangalore      0
# 4  335982        1  Kolkata Knight Riders  Royal Challengers Bangalore      0
#
#    ballnumber       batter   bowler  non-striker  batsman_run  extras_run  \
# 0           1   SC Ganguly  P Kumar  BB McCullum            0           1
# 1           2  BB McCullum  P Kumar   SC Ganguly            0           0
# 2           3  BB McCullum  P Kumar   SC Ganguly            0           1
# 3           4  BB McCullum  P Kumar   SC Ganguly            0           0
# 4           5  BB McCullum  P Kumar   SC Ganguly            0           0
#
#    total_run extra_type  isWicketDelivery player_out kind fielders_involved
# 0          1    legbyes                 0        NaN  NaN               NaN
# 1          0        NaN                 0        NaN  NaN               NaN
# 2          1      wides                 0        NaN  NaN               NaN
# 3          0        NaN                 0        NaN  NaN               NaN
# 4          0        NaN                 0        NaN  NaN               NaN

# %%
second_dataset.head()
# Out:
#        ID   Season        City     Date match_type Player_of_Match  \
# 0  335982  2007/08   Bangalore  4/18/08     League     BB McCullum
# 1  335983  2007/08  Chandigarh  4/19/08     League      MEK Hussey
# 2  335984  2007/08       Delhi  4/19/08     League     MF Maharoof
# 3  335985  2007/08      Mumbai  4/20/08     League      MV Boucher
# 4  335986  2007/08     Kolkata  4/20/08     League       DJ Hussey
#
#                                         Venue                        Team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          Team2                   TossWinner TossDecision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore        field
# 1          Chennai Super Kings          Chennai Super Kings          bat
# 2             Rajasthan Royals             Rajasthan Royals          bat
# 3  Royal Challengers Bangalore               Mumbai Indians          bat
# 4              Deccan Chargers              Deccan Chargers          bat
#
#                    WinningTeam    WonBy  Margin  target_runs  target_overs  \
# 0        Kolkata Knight Riders     runs   140.0        223.0          20.0
# 1          Chennai Super Kings     runs    33.0        241.0          20.0
# 2             Delhi Daredevils  wickets     9.0        130.0          20.0
# 3  Royal Challengers Bangalore  wickets     5.0        166.0          20.0
# 4        Kolkata Knight Riders  wickets     5.0        111.0          20.0
#
#   SuperOver method    Umpire1         Umpire2
# 0         N    NaN  Asad Rauf     RE Koertzen
# 1         N    NaN  MR Benson      SL Shastri
# 2         N    NaN  Aleem Dar  GA Pratapkumar
# 3         N    NaN   SJ Davis       DJ Harper
# 4         N    NaN  BF Bowden     K Hariharan

# %%
first_dataset.columns
# Out:
# Index(['ID', 'innings', 'BattingTeam', 'BowlingTeam', 'overs', 'ballnumber',
#        'batter', 'bowler', 'non-striker', 'batsman_run', 'extras_run',
#        'total_run', 'extra_type', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved'],
#       dtype='object')

# %%
total_runs = first_dataset.groupby(['ID','innings']).sum()['total_run'].add(1).reset_index()

# %%
total_runs
# Out:
#            ID  innings  total_run
# 0      335982        1        223
# 1      335982        2         83
# 2      335983        1        241
# 3      335983        2        208
# 4      335984        1        130
# ...       ...      ...        ...
# 2212  1426310        2        175
# 2213  1426311        1        176
# 2214  1426311        2        140
# 2215  1426312        1        114
# 2216  1426312        2        115
#
# [2217 rows x 3 columns]

# %%
total_runs = total_runs[total_runs['innings']==1]

# %%
match_df = second_dataset.merge(total_runs[['ID','total_run']],left_on='ID',right_on='ID')

# %%
match_df
# Out:
#            ID   Season        City     Date   match_type  Player_of_Match  \
# 0      335982  2007/08   Bangalore  4/18/08       League      BB McCullum
# 1      335983  2007/08  Chandigarh  4/19/08       League       MEK Hussey
# 2      335984  2007/08       Delhi  4/19/08       League      MF Maharoof
# 3      335985  2007/08      Mumbai  4/20/08       League       MV Boucher
# 4      335986  2007/08     Kolkata  4/20/08       League        DJ Hussey
# ...       ...      ...         ...      ...          ...              ...
# 1090  1426307     2024   Hyderabad  5/19/24       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  5/21/24  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  5/22/24   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  5/24/24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  5/26/24        Final         MA Starc
#
#                                                   Venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             Team1                        Team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                        TossWinner  ...                  WinningTeam    WonBy  \
# 0     Royal Challengers Bangalore  ...        Kolkata Knight Riders     runs
# 1             Chennai Super Kings  ...          Chennai Super Kings     runs
# 2                Rajasthan Royals  ...             Delhi Daredevils  wickets
# 3                  Mumbai Indians  ...  Royal Challengers Bangalore  wickets
# 4                 Deccan Chargers  ...        Kolkata Knight Riders  wickets
# ...                           ...  ...                          ...      ...
# 1090                 Punjab Kings  ...          Sunrisers Hyderabad  wickets
# 1091          Sunrisers Hyderabad  ...        Kolkata Knight Riders  wickets
# 1092             Rajasthan Royals  ...             Rajasthan Royals  wickets
# 1093             Rajasthan Royals  ...          Sunrisers Hyderabad     runs
# 1094          Sunrisers Hyderabad  ...        Kolkata Knight Riders  wickets
#
#      Margin  target_runs  target_overs  SuperOver method  \
# 0     140.0        223.0          20.0          N    NaN
# 1      33.0        241.0          20.0          N    NaN
# 2       9.0        130.0          20.0          N    NaN
# 3       5.0        166.0          20.0          N    NaN
# 4       5.0        111.0          20.0          N    NaN
# ...     ...          ...           ...        ...    ...
# 1090    4.0        215.0          20.0          N    NaN
# 1091    8.0        160.0          20.0          N    NaN
# 1092    4.0        173.0          20.0          N    NaN
# 1093   36.0        176.0          20.0          N    NaN
# 1094    8.0        114.0          20.0          N    NaN
#
#                     Umpire1               Umpire2 total_run
# 0                 Asad Rauf           RE Koertzen       223
# 1                 MR Benson            SL Shastri       241
# 2                 Aleem Dar        GA Pratapkumar       130
# 3                  SJ Davis             DJ Harper       166
# 4                 BF Bowden           K Hariharan       111
# ...                     ...                   ...       ...
# 1090            Nitin Menon             VK Sharma       215
# 1091           AK Chaudhary              R Pandit       160
# 1092  KN Ananthapadmanabhan  MV Saidharshan Kumar       173
# 1093            Nitin Menon             VK Sharma       176
# 1094          J Madanagopal           Nitin Menon       114
#
# [1095 rows x 21 columns]

# %%
match_df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Kings XI Punjab                 92
# Sunrisers Hyderabad             86
# Delhi Daredevils                85
# Delhi Capitals                  41
# Deccan Chargers                 39
# Punjab Kings                    31
# Lucknow Super Giants            23
# Pune Warriors                   23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %%
match_df['Team1'] = match_df['Team1'].replace('Delhi Daredevils','Delhi Capitals')
match_df['Team2'] = match_df['Team2'].replace('Delhi Daredevils','Delhi Capitals')

match_df['Team1'] = match_df['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2'] = match_df['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['Team1'] = match_df['Team1'].replace('Kings XI Punjab','Punjab Kings')
match_df['Team2'] = match_df['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
match_df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Delhi Capitals                 126
# Sunrisers Hyderabad            125
# Punjab Kings                   123
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Pune Warriors                   23
# Lucknow Super Giants            23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           7
# Name: Team1, dtype: int64

# %%
teams = ['Kolkata Knight Riders', 
         'Chennai Super Kings',
         'Punjab Kings', 
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad',
         'Lucknow Super Giants',
         'Gujarat Titans'
         ]

# %%
match_df = match_df[match_df['Team1'].isin(teams)]
match_df = match_df[match_df['Team2'].isin(teams)]

# %%
match_df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    127
# Chennai Super Kings            124
# Delhi Capitals                 118
# Sunrisers Hyderabad            117
# Punjab Kings                   115
# Mumbai Indians                 113
# Kolkata Knight Riders          113
# Rajasthan Royals                97
# Lucknow Super Giants            22
# Gujarat Titans                  19
# Name: Team1, dtype: int64

# %%
match_df.shape
# Out:
# (965, 21)

# %%
match_df = match_df[['ID','City','WinningTeam','total_run', 'Team1', 'Team2']]

# %%
match_df.shape
# Out:
# (965, 6)

# %%
second_innings = match_df.merge(first_dataset,on='ID')
second_innings
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 0        335982  Bangalore  Kolkata Knight Riders          223
# 1        335982  Bangalore  Kolkata Knight Riders          223
# 2        335982  Bangalore  Kolkata Knight Riders          223
# 3        335982  Bangalore  Kolkata Knight Riders          223
# 4        335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 0       Royal Challengers Bangalore  Kolkata Knight Riders        1
# 1       Royal Challengers Bangalore  Kolkata Knight Riders        1
# 2       Royal Challengers Bangalore  Kolkata Knight Riders        1
# 3       Royal Challengers Bangalore  Kolkata Knight Riders        1
# 4       Royal Challengers Bangalore  Kolkata Knight Riders        1
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                   BattingTeam                  BowlingTeam  overs  ...  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore      0  ...
# 1       Kolkata Knight Riders  Royal Challengers Bangalore      0  ...
# 2       Kolkata Knight Riders  Royal Challengers Bangalore      0  ...
# 3       Kolkata Knight Riders  Royal Challengers Bangalore      0  ...
# 4       Kolkata Knight Riders  Royal Challengers Bangalore      0  ...
# ...                       ...                          ...    ...  ...
# 230277  Kolkata Knight Riders          Sunrisers Hyderabad      9  ...
# 230278  Kolkata Knight Riders          Sunrisers Hyderabad      9  ...
# 230279  Kolkata Knight Riders          Sunrisers Hyderabad     10  ...
# 230280  Kolkata Knight Riders          Sunrisers Hyderabad     10  ...
# 230281  Kolkata Knight Riders          Sunrisers Hyderabad     10  ...
#
#                bowler  non-striker batsman_run extras_run  total_run_y  \
# 0             P Kumar  BB McCullum           0          1            1
# 1             P Kumar   SC Ganguly           0          0            0
# 2             P Kumar   SC Ganguly           0          1            1
# 3             P Kumar   SC Ganguly           0          0            0
# 4             P Kumar   SC Ganguly           0          0            0
# ...               ...          ...         ...        ...          ...
# 230277     AK Markram      VR Iyer           1          0            1
# 230278     AK Markram      SS Iyer           1          0            1
# 230279  Shahbaz Ahmed      SS Iyer           1          0            1
# 230280  Shahbaz Ahmed      VR Iyer           1          0            1
# 230281  Shahbaz Ahmed      SS Iyer           1          0            1
#
#         extra_type  isWicketDelivery player_out  kind fielders_involved
# 0          legbyes                 0        NaN   NaN               NaN
# 1              NaN                 0        NaN   NaN               NaN
# 2            wides                 0        NaN   NaN               NaN
# 3              NaN                 0        NaN   NaN               NaN
# 4              NaN                 0        NaN   NaN               NaN
# ...            ...               ...        ...   ...               ...
# 230277         NaN                 0        NaN   NaN               NaN
# 230278         NaN                 0        NaN   NaN               NaN
# 230279         NaN                 0        NaN   NaN               NaN
# 230280         NaN                 0        NaN   NaN               NaN
# 230281         NaN                 0        NaN   NaN               NaN
#
# [230282 rows x 22 columns]

# %%
second_innings = second_innings[second_innings['innings']==2]
second_innings.shape
# Out:
# (111082, 22)

# %%
second_innings
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#                bowler non-striker batsman_run extras_run  total_run_y  \
# 124          AB Dinda    W Jaffer           1          0            1
# 125          AB Dinda    R Dravid           0          1            1
# 126          AB Dinda    R Dravid           0          0            0
# 127          AB Dinda    R Dravid           1          0            1
# 128          AB Dinda    W Jaffer           1          0            1
# ...               ...         ...         ...        ...          ...
# 230277     AK Markram     VR Iyer           1          0            1
# 230278     AK Markram     SS Iyer           1          0            1
# 230279  Shahbaz Ahmed     SS Iyer           1          0            1
# 230280  Shahbaz Ahmed     VR Iyer           1          0            1
# 230281  Shahbaz Ahmed     SS Iyer           1          0            1
#
#         extra_type  isWicketDelivery player_out  kind fielders_involved
# 124            NaN                 0        NaN   NaN               NaN
# 125          wides                 0        NaN   NaN               NaN
# 126            NaN                 0        NaN   NaN               NaN
# 127            NaN                 0        NaN   NaN               NaN
# 128            NaN                 0        NaN   NaN               NaN
# ...            ...               ...        ...   ...               ...
# 230277         NaN                 0        NaN   NaN               NaN
# 230278         NaN                 0        NaN   NaN               NaN
# 230279         NaN                 0        NaN   NaN               NaN
# 230280         NaN                 0        NaN   NaN               NaN
# 230281         NaN                 0        NaN   NaN               NaN
#
# [111082 rows x 22 columns]

# %%
second_innings['Team1'] = second_innings['Team1'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['Team2'] = second_innings['Team2'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['Team1'] = second_innings['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['Team2'] = second_innings['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['Team1'] = second_innings['Team1'].replace('Kings XI Punjab','Punjab Kings')
second_innings['Team2'] = second_innings['Team2'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/340332489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Delhi Daredevils','Delhi Capitals')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/340332489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Delhi Daredevils','Delhi Capitals')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/340332489.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/340332489.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/340332489.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Kings XI Punjab','Punjab Kings')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/340332489.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings['Team1'].value_counts()
# Out:
# Chennai Super Kings            14752
# Royal Challengers Bangalore    14289
# Sunrisers Hyderabad            13535
# Delhi Capitals                 13513
# Punjab Kings                   13229
# Mumbai Indians                 13162
# Kolkata Knight Riders          12771
# Rajasthan Royals               11186
# Lucknow Super Giants            2488
# Gujarat Titans                  2157
# Name: Team1, dtype: int64

# %%
second_innings.columns
# Out:
# Index(['ID', 'City', 'WinningTeam', 'total_run_x', 'Team1', 'Team2', 'innings',
#        'BattingTeam', 'BowlingTeam', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'batsman_run', 'extras_run', 'total_run_y', 'extra_type',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved'],
#       dtype='object')

# %%
second_innings.shape
# Out:
# (111082, 22)

# %%
# Function to determine the bowling team
def determine_bowling_team(row):
    if row['BattingTeam'] == row['Team1']:
        return row['Team2']
    else:
        return row['Team1']

# Create the new 'BowlingTeam' column
second_innings['BowlingTeam'] = second_innings.apply(determine_bowling_team, axis=1)
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1899240566.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings.apply(determine_bowling_team, axis=1)

# %%
second_innings.tail(103)
# Out:
#              ID     City            WinningTeam  total_run_x  \
# 230062  1426311  Chennai    Sunrisers Hyderabad          176
# 230063  1426311  Chennai    Sunrisers Hyderabad          176
# 230064  1426311  Chennai    Sunrisers Hyderabad          176
# 230065  1426311  Chennai    Sunrisers Hyderabad          176
# 230066  1426311  Chennai    Sunrisers Hyderabad          176
# ...         ...      ...                    ...          ...
# 230277  1426312  Chennai  Kolkata Knight Riders          114
# 230278  1426312  Chennai  Kolkata Knight Riders          114
# 230279  1426312  Chennai  Kolkata Knight Riders          114
# 230280  1426312  Chennai  Kolkata Knight Riders          114
# 230281  1426312  Chennai  Kolkata Knight Riders          114
#
#                       Team1                  Team2  innings  \
# 230062  Sunrisers Hyderabad       Rajasthan Royals        2
# 230063  Sunrisers Hyderabad       Rajasthan Royals        2
# 230064  Sunrisers Hyderabad       Rajasthan Royals        2
# 230065  Sunrisers Hyderabad       Rajasthan Royals        2
# 230066  Sunrisers Hyderabad       Rajasthan Royals        2
# ...                     ...                    ...      ...
# 230277  Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278  Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279  Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280  Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281  Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                   BattingTeam          BowlingTeam  overs  ...         bowler  \
# 230062       Rajasthan Royals  Sunrisers Hyderabad     14  ...  Shahbaz Ahmed
# 230063       Rajasthan Royals  Sunrisers Hyderabad     14  ...  Shahbaz Ahmed
# 230064       Rajasthan Royals  Sunrisers Hyderabad     14  ...  Shahbaz Ahmed
# 230065       Rajasthan Royals  Sunrisers Hyderabad     14  ...  Shahbaz Ahmed
# 230066       Rajasthan Royals  Sunrisers Hyderabad     14  ...  Shahbaz Ahmed
# ...                       ...                  ...    ...  ...            ...
# 230277  Kolkata Knight Riders  Sunrisers Hyderabad      9  ...     AK Markram
# 230278  Kolkata Knight Riders  Sunrisers Hyderabad      9  ...     AK Markram
# 230279  Kolkata Knight Riders  Sunrisers Hyderabad     10  ...  Shahbaz Ahmed
# 230280  Kolkata Knight Riders  Sunrisers Hyderabad     10  ...  Shahbaz Ahmed
# 230281  Kolkata Knight Riders  Sunrisers Hyderabad     10  ...  Shahbaz Ahmed
#
#         non-striker batsman_run extras_run  total_run_y  extra_type  \
# 230062  Dhruv Jurel           0          0            0         NaN
# 230063  Dhruv Jurel           0          0            0         NaN
# 230064  Dhruv Jurel           1          0            1         NaN
# 230065     R Powell           4          0            4         NaN
# 230066     R Powell           4          0            4         NaN
# ...             ...         ...        ...          ...         ...
# 230277      VR Iyer           1          0            1         NaN
# 230278      SS Iyer           1          0            1         NaN
# 230279      SS Iyer           1          0            1         NaN
# 230280      VR Iyer           1          0            1         NaN
# 230281      SS Iyer           1          0            1         NaN
#
#         isWicketDelivery player_out  kind fielders_involved
# 230062                 0        NaN   NaN               NaN
# 230063                 0        NaN   NaN               NaN
# 230064                 0        NaN   NaN               NaN
# 230065                 0        NaN   NaN               NaN
# 230066                 0        NaN   NaN               NaN
# ...                  ...        ...   ...               ...
# 230277                 0        NaN   NaN               NaN
# 230278                 0        NaN   NaN               NaN
# 230279                 0        NaN   NaN               NaN
# 230280                 0        NaN   NaN               NaN
# 230281                 0        NaN   NaN               NaN
#
# [103 rows x 22 columns]

# %%
second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1361729818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1361729818.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Delhi Daredevils','Delhi Capitals')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1361729818.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1361729818.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1361729818.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1361729818.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#                bowler non-striker batsman_run extras_run  total_run_y  \
# 124          AB Dinda    W Jaffer           1          0            1
# 125          AB Dinda    R Dravid           0          1            1
# 126          AB Dinda    R Dravid           0          0            0
# 127          AB Dinda    R Dravid           1          0            1
# 128          AB Dinda    W Jaffer           1          0            1
# ...               ...         ...         ...        ...          ...
# 230277     AK Markram     VR Iyer           1          0            1
# 230278     AK Markram     SS Iyer           1          0            1
# 230279  Shahbaz Ahmed     SS Iyer           1          0            1
# 230280  Shahbaz Ahmed     VR Iyer           1          0            1
# 230281  Shahbaz Ahmed     SS Iyer           1          0            1
#
#         extra_type  isWicketDelivery player_out  kind fielders_involved
# 124            NaN                 0        NaN   NaN               NaN
# 125          wides                 0        NaN   NaN               NaN
# 126            NaN                 0        NaN   NaN               NaN
# 127            NaN                 0        NaN   NaN               NaN
# 128            NaN                 0        NaN   NaN               NaN
# ...            ...               ...        ...   ...               ...
# 230277         NaN                 0        NaN   NaN               NaN
# 230278         NaN                 0        NaN   NaN               NaN
# 230279         NaN                 0        NaN   NaN               NaN
# 230280         NaN                 0        NaN   NaN               NaN
# 230281         NaN                 0        NaN   NaN               NaN
#
# [111082 rows x 22 columns]

# %%
second_innings['BowlingTeam'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Sunrisers Hyderabad', 'Chennai Super Kings',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Lucknow Super Giants', 'Gujarat Titans'], dtype=object)

# %%
second_innings['current_Score'] = second_innings.groupby('ID').cumsum()['total_run_y']
second_innings
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/3076402150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['current_Score'] = second_innings.groupby('ID').cumsum()['total_run_y']
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#         non-striker batsman_run extras_run total_run_y  extra_type  \
# 124        W Jaffer           1          0           1         NaN
# 125        R Dravid           0          1           1       wides
# 126        R Dravid           0          0           0         NaN
# 127        R Dravid           1          0           1         NaN
# 128        W Jaffer           1          0           1         NaN
# ...             ...         ...        ...         ...         ...
# 230277      VR Iyer           1          0           1         NaN
# 230278      SS Iyer           1          0           1         NaN
# 230279      SS Iyer           1          0           1         NaN
# 230280      VR Iyer           1          0           1         NaN
# 230281      SS Iyer           1          0           1         NaN
#
#         isWicketDelivery  player_out kind  fielders_involved current_Score
# 124                    0         NaN  NaN                NaN             1
# 125                    0         NaN  NaN                NaN             2
# 126                    0         NaN  NaN                NaN             2
# 127                    0         NaN  NaN                NaN             3
# 128                    0         NaN  NaN                NaN             4
# ...                  ...         ...  ...                ...           ...
# 230277                 0         NaN  NaN                NaN           110
# 230278                 0         NaN  NaN                NaN           111
# 230279                 0         NaN  NaN                NaN           112
# 230280                 0         NaN  NaN                NaN           113
# 230281                 0         NaN  NaN                NaN           114
#
# [111082 rows x 23 columns]

# %%
second_innings['runs_left'] = second_innings['total_run_x'] - second_innings['current_Score']
second_innings
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/802083827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['runs_left'] = second_innings['total_run_x'] - second_innings['current_Score']
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#         batsman_run extras_run total_run_y extra_type  isWicketDelivery  \
# 124               1          0           1        NaN                 0
# 125               0          1           1      wides                 0
# 126               0          0           0        NaN                 0
# 127               1          0           1        NaN                 0
# 128               1          0           1        NaN                 0
# ...             ...        ...         ...        ...               ...
# 230277            1          0           1        NaN                 0
# 230278            1          0           1        NaN                 0
# 230279            1          0           1        NaN                 0
# 230280            1          0           1        NaN                 0
# 230281            1          0           1        NaN                 0
#
#         player_out  kind fielders_involved  current_Score runs_left
# 124            NaN   NaN               NaN              1       222
# 125            NaN   NaN               NaN              2       221
# 126            NaN   NaN               NaN              2       221
# 127            NaN   NaN               NaN              3       220
# 128            NaN   NaN               NaN              4       219
# ...            ...   ...               ...            ...       ...
# 230277         NaN   NaN               NaN            110         4
# 230278         NaN   NaN               NaN            111         3
# 230279         NaN   NaN               NaN            112         2
# 230280         NaN   NaN               NaN            113         1
# 230281         NaN   NaN               NaN            114         0
#
# [111082 rows x 24 columns]

# %%
second_innings['balls_left'] = 126 - (second_innings['overs']*6 +second_innings['ballnumber'])
second_innings
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/2820591732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['balls_left'] = 126 - (second_innings['overs']*6 +second_innings['ballnumber'])
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#         extras_run total_run_y extra_type isWicketDelivery  player_out  kind  \
# 124              0           1        NaN                0         NaN   NaN
# 125              1           1      wides                0         NaN   NaN
# 126              0           0        NaN                0         NaN   NaN
# 127              0           1        NaN                0         NaN   NaN
# 128              0           1        NaN                0         NaN   NaN
# ...            ...         ...        ...              ...         ...   ...
# 230277           0           1        NaN                0         NaN   NaN
# 230278           0           1        NaN                0         NaN   NaN
# 230279           0           1        NaN                0         NaN   NaN
# 230280           0           1        NaN                0         NaN   NaN
# 230281           0           1        NaN                0         NaN   NaN
#
#         fielders_involved current_Score  runs_left balls_left
# 124                   NaN             1        222        125
# 125                   NaN             2        221        124
# 126                   NaN             2        221        123
# 127                   NaN             3        220        122
# 128                   NaN             4        219        121
# ...                   ...           ...        ...        ...
# 230277                NaN           110          4         67
# 230278                NaN           111          3         66
# 230279                NaN           112          2         65
# 230280                NaN           113          1         64
# 230281                NaN           114          0         63
#
# [111082 rows x 25 columns]

# %%
second_innings.columns
# Out:
# Index(['ID', 'City', 'WinningTeam', 'total_run_x', 'Team1', 'Team2', 'innings',
#        'BattingTeam', 'BowlingTeam', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'batsman_run', 'extras_run', 'total_run_y', 'extra_type',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'current_Score', 'runs_left', 'balls_left'],
#       dtype='object')

# %%
# Select the columns of interest
columns_to_check = ['current_Score', 'runs_left', 'balls_left']

# Check how many values in each column are negative
negative_counts = second_innings[columns_to_check].lt(0).sum()

# Display the counts
print("Number of negative values in each column:")
print(negative_counts)
# Out:
# Number of negative values in each column:
# current_Score      0
# runs_left        303
# balls_left         0
# dtype: int64

# %%
second_innings['player_out'] = second_innings['player_out'].fillna("0")
second_innings['player_out'] = second_innings['player_out'].apply(lambda x:x if x=="0" else "1")
second_innings['player_out'] = second_innings['player_out'].astype('int')
wickets = second_innings.groupby('ID').cumsum()['player_out']
second_innings['wickets_remaining'] = 10-wickets
second_innings
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1997531377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].fillna("0")
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1997531377.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].apply(lambda x:x if x=="0" else "1")
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1997531377.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].astype('int')
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1997531377.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['wickets_remaining'] = 10-wickets
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#         total_run_y extra_type isWicketDelivery player_out  kind  \
# 124               1        NaN                0          0   NaN
# 125               1      wides                0          0   NaN
# 126               0        NaN                0          0   NaN
# 127               1        NaN                0          0   NaN
# 128               1        NaN                0          0   NaN
# ...             ...        ...              ...        ...   ...
# 230277            1        NaN                0          0   NaN
# 230278            1        NaN                0          0   NaN
# 230279            1        NaN                0          0   NaN
# 230280            1        NaN                0          0   NaN
# 230281            1        NaN                0          0   NaN
#
#         fielders_involved  current_Score runs_left  balls_left  \
# 124                   NaN              1       222         125
# 125                   NaN              2       221         124
# 126                   NaN              2       221         123
# 127                   NaN              3       220         122
# 128                   NaN              4       219         121
# ...                   ...            ...       ...         ...
# 230277                NaN            110         4          67
# 230278                NaN            111         3          66
# 230279                NaN            112         2          65
# 230280                NaN            113         1          64
# 230281                NaN            114         0          63
#
#         wickets_remaining
# 124                    10
# 125                    10
# 126                    10
# 127                    10
# 128                    10
# ...                   ...
# 230277                  8
# 230278                  8
# 230279                  8
# 230280                  8
# 230281                  8
#
# [111082 rows x 26 columns]

# %%
second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
second_innings
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1691903609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/1691903609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#         isWicketDelivery player_out kind fielders_involved  current_Score  \
# 124                    0          0  NaN               NaN              1
# 125                    0          0  NaN               NaN              2
# 126                    0          0  NaN               NaN              2
# 127                    0          0  NaN               NaN              3
# 128                    0          0  NaN               NaN              4
# ...                  ...        ...  ...               ...            ...
# 230277                 0          0  NaN               NaN            110
# 230278                 0          0  NaN               NaN            111
# 230279                 0          0  NaN               NaN            112
# 230280                 0          0  NaN               NaN            113
# 230281                 0          0  NaN               NaN            114
#
#         runs_left  balls_left wickets_remaining    crr    rrr
# 124           222         125                10  -1.20  10.66
# 125           221         124                10  -3.00  10.69
# 126           221         123                10  -4.00  10.78
# 127           220         122                10  -9.00  10.82
# 128           219         121                10 -24.00  10.86
# ...           ...         ...               ...    ...    ...
# 230277          4          67                 8  12.45   0.36
# 230278          3          66                 8  12.33   0.27
# 230279          2          65                 8  12.22   0.18
# 230280          1          64                 8  12.11   0.09
# 230281          0          63                 8  12.00   0.00
#
# [111082 rows x 28 columns]

# %%
def winner(team):
    return 1 if team['BattingTeam'] == team['WinningTeam'] else 0

# %%
second_innings['results'] = second_innings.apply(winner,axis=1)
second_innings
# Out:
# /var/folders/x7/gt1_njjn435g742snp4jzlr40000gn/T/ipykernel_3347/3111665595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['results'] = second_innings.apply(winner,axis=1)
#              ID       City            WinningTeam  total_run_x  \
# 124      335982  Bangalore  Kolkata Knight Riders          223
# 125      335982  Bangalore  Kolkata Knight Riders          223
# 126      335982  Bangalore  Kolkata Knight Riders          223
# 127      335982  Bangalore  Kolkata Knight Riders          223
# 128      335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 230277  1426312    Chennai  Kolkata Knight Riders          114
# 230278  1426312    Chennai  Kolkata Knight Riders          114
# 230279  1426312    Chennai  Kolkata Knight Riders          114
# 230280  1426312    Chennai  Kolkata Knight Riders          114
# 230281  1426312    Chennai  Kolkata Knight Riders          114
#
#                               Team1                  Team2  innings  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        2
# ...                             ...                    ...      ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders        2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders        2
#
#                         BattingTeam            BowlingTeam  overs  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders      0  ...
# ...                             ...                    ...    ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad      9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad     10  ...
#
#         player_out kind fielders_involved current_Score  runs_left  \
# 124              0  NaN               NaN             1        222
# 125              0  NaN               NaN             2        221
# 126              0  NaN               NaN             2        221
# 127              0  NaN               NaN             3        220
# 128              0  NaN               NaN             4        219
# ...            ...  ...               ...           ...        ...
# 230277           0  NaN               NaN           110          4
# 230278           0  NaN               NaN           111          3
# 230279           0  NaN               NaN           112          2
# 230280           0  NaN               NaN           113          1
# 230281           0  NaN               NaN           114          0
#
#         balls_left  wickets_remaining    crr    rrr  results
# 124            125                 10  -1.20  10.66        0
# 125            124                 10  -3.00  10.69        0
# 126            123                 10  -4.00  10.78        0
# 127            122                 10  -9.00  10.82        0
# 128            121                 10 -24.00  10.86        0
# ...            ...                ...    ...    ...      ...
# 230277          67                  8  12.45   0.36        1
# 230278          66                  8  12.33   0.27        1
# 230279          65                  8  12.22   0.18        1
# 230280          64                  8  12.11   0.09        1
# 230281          63                  8  12.00   0.00        1
#
# [111082 rows x 29 columns]

# %%
required_data = second_innings[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets_remaining','total_run_x','crr','rrr','results']]
required_data
# Out:
#                         BattingTeam            BowlingTeam       City  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_remaining  total_run_x    crr    rrr  \
# 124           222         125                 10          223  -1.20  10.66
# 125           221         124                 10          223  -3.00  10.69
# 126           221         123                 10          223  -4.00  10.78
# 127           220         122                 10          223  -9.00  10.82
# 128           219         121                 10          223 -24.00  10.86
# ...           ...         ...                ...          ...    ...    ...
# 230277          4          67                  8          114  12.45   0.36
# 230278          3          66                  8          114  12.33   0.27
# 230279          2          65                  8          114  12.22   0.18
# 230280          1          64                  8          114  12.11   0.09
# 230281          0          63                  8          114  12.00   0.00
#
#         results
# 124           0
# 125           0
# 126           0
# 127           0
# 128           0
# ...         ...
# 230277        1
# 230278        1
# 230279        1
# 230280        1
# 230281        1
#
# [111082 rows x 10 columns]

# %%
required_data = required_data.replace([np.inf, -np.inf], np.nan)
required_data = required_data.dropna()

# %%
required_data = required_data[required_data['crr'] >= 0]

# %%
columns_to_check = ['runs_left', 'balls_left', 'wickets_remaining', 'total_run_x', 'crr', 'rrr', 'results']

required_data = required_data[~(required_data[columns_to_check] < 0).any(axis=1)]

# %%
required_data.head()
# Out:
#                      BattingTeam            BowlingTeam       City  runs_left  \
# 130  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        219
# 131  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        219
# 132  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        219
# 133  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        215
# 134  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        214
#
#      balls_left  wickets_remaining  total_run_x   crr    rrr  results
# 130         119                 10          223  24.0  11.04        0
# 131         119                  9          223  24.0  11.04        0
# 132         118                  9          223  12.0  11.14        0
# 133         117                  9          223  16.0  11.03        0
# 134         116                  9          223  13.5  11.07        0

# %%
# Assuming your DataFrame is named 'df'
required_data.rename(columns={'BattingTeam': 'batting_team', 'BowlingTeam': 'bowling_team', 'City': 'city'}, inplace=True)
required_data
# Out:
#                        batting_team           bowling_team       city  \
# 130     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 131     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 132     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 133     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 134     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_remaining  total_run_x    crr    rrr  \
# 130           219         119                 10          223  24.00  11.04
# 131           219         119                  9          223  24.00  11.04
# 132           219         118                  9          223  12.00  11.14
# 133           215         117                  9          223  16.00  11.03
# 134           214         116                  9          223  13.50  11.07
# ...           ...         ...                ...          ...    ...    ...
# 230277          4          67                  8          114  12.45   0.36
# 230278          3          66                  8          114  12.33   0.27
# 230279          2          65                  8          114  12.22   0.18
# 230280          1          64                  8          114  12.11   0.09
# 230281          0          63                  8          114  12.00   0.00
#
#         results
# 130           0
# 131           0
# 132           0
# 133           0
# 134           0
# ...         ...
# 230277        1
# 230278        1
# 230279        1
# 230280        1
# 230281        1
#
# [100427 rows x 10 columns]

# %%
numeric = required_data[['runs_left', 'balls_left', 'wickets_remaining', 'total_run_x', 'crr', 'rrr', 'results']]
has_infinite_values = np.any(np.isinf(numeric))

# Check for negative values in the entire DataFrame
has_negative_values = (numeric < 0).any().any()

# Check for null values in the entire DataFrame
has_null_values = numeric.isnull().any().any()

# Display the results
print(f"Has Infinite Values: {has_infinite_values}")
print(f"Has Negative Values: {has_negative_values}")
print(f"Has Null Values: {has_null_values}")
# Out:
# Has Infinite Values: False
# Has Negative Values: False
# Has Null Values: False

# %%
required_data.to_csv("FinalIPLDataSet.csv", index=False)
